# %%
from boltzSolver import sol,x
import matplotlib.pyplot as plt
import numpy as np

plt.plot(sol.t, sol.y[0])
plt.yscale('log')
plt.xscale('log')
plt.title('Freeze-out model, with dark matter as a Dirac fermion')
plt.xlabel('x (m_DM/T)')
plt.ylabel('Yield')
plt.savefig('freeze-out, modelo 1')
np.savetxt('data modelo 1', np.column_stack([sol.t,sol.y[0]]))
# Out:
# [['xd', [], array([6.20300929e-14, 6.20296233e-14, 6.20291537e-14, ...,
#        6.84685001e-15, 6.84685001e-15, 6.84685001e-15])], ['xd', [], array([0., 0., 0., ..., 0., 0., 0.])]]
# x 1.0 dY [-0.]
# x 1.0004333333333333 dY [-23.15843937]
# x 1.0004333333333333 dY [63922.81645822]
# x 1.0001083333333334 dY [-5.79484398]
# x 1.0001083333333334 dY [11565.74411239]
# x 1.0000270833333333 dY [-1.4490383]
# x 1.0000270833333333 dY [751.69972196]
# x 1.0000067708333333 dY [-0.36228003]
# x 1.0000067708333333 dY [46.8304775]
# x 1.0000016927083333 dY [-0.09057163]
# x 1.0000016927083333 dY [2.85953271]
# x 1.0000004231770834 dY [-0.02264297]
# x 1.0000004231770834 dY [0.16174127]
# x 1.000000105794271 dY [-0.00566075]
# x 1.000000105794271 dY [0.00586329]
# x 1.0000000264485678 dY [-0.00141519]
# x 1.0000000264485678 dY [-0.00069493]
# x 1.0000000264485678 dY [-0.0010615]
# x 1.000000006612142 dY [-0.0003538]
# x 1.000000006612142 dY [-0.00030878]
# x 1.000000013224284 dY [-0.00062902]
# ...

# %%
from auxFunc import entropydensity

mDM = 1300
x = mDM/3
s = 2891.2 #entropydensity(x, mDM)
y = 8.72 * 10**(-8)
rho_c = 4.79 * 10**(-6)
omegah2 = ((s * mDM * y)/rho_c) * (0.674)**2
print(omegah2)
# Out:
# 31082.951595664308
