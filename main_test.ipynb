# %%
from boltzSolver import sol1, sol2, sol3, sol4
import matplotlib.pyplot as plt
import numpy as np

solydm = [*sol1.y[0], *sol2.y[0], *sol3.y[0], *sol4.y[0]]
solyul = [*sol1.y[1], *sol2.y[1], *sol3.y[1], *sol4.y[1]]
solt = [*sol1.t, *sol2.t, *sol3.t, *sol4.t]

plt.plot(solt, solydm, label='DM')
plt.plot(solt, solyul, label='ul')
plt.legend()
plt.yscale('log')
plt.xscale('log')
plt.title('Coann model, with dark matter as a Dirac fermion and partner as ul')
plt.xlabel('x (m_DM/T)')
plt.ylabel('Yield')
plt.savefig('coann, model xd-ul')
np.savetxt('data model xd-ul', np.column_stack([solt,solydm, solyul]))
# Out:
# [['xd', ['ul'], array([0., 0., 0., ..., 0., 0., 0.])], ['xd', [], array([1.55209661e-13, 1.55209522e-13, 1.55209382e-13, ...,
#        6.84685001e-15, 6.84685001e-15, 6.84685001e-15])], ['ul', [], array([1.29064189e-07, 1.29064248e-07, 1.29064308e-07, ...,
#        2.94782672e-07, 2.94782672e-07, 2.94782672e-07])]]
# check 1 2
# check 2 4
# spin 2
# flavour 1
# anti 1
# [['ul', ['xd'], array([0., 0., 0., ..., 0., 0., 0.])], ['ul', [], array([1.98904542e-07, 1.98904545e-07, 1.98904548e-07, ...,
#        2.03462638e-07, 2.03462638e-07, 2.03462638e-07])], ['xd', [], array([1.29064189e-07, 1.29064248e-07, 1.29064308e-07, ...,
#        2.94782672e-07, 2.94782672e-07, 2.94782672e-07])]]
# check 1 3
# check 2 6
# spin 1
# flavour 3
# anti 1
# c:\Users\Gabi\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\integrate\_ivp\ivp.py:616: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
# ...

# %%
from auxFunc import entropydensity

mDM = 500
s = 2889.2 #entropydensity(x, mDM)
y = 1.95 * 10**(-11)
rho_c = 1.05 * 10**(-5)
omegah2 = ((s * mDM * y)/rho_c)
print(omegah2)
# Out:
# 2.682828571428571
